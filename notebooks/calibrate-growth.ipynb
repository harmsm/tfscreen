# %%
import tfscreen
from tfscreen.calibration import (
    calibrate,
    plot
)

import matplotlib.pyplot as plt
    
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
df = tfscreen.util.read_dataframe("input/raw-compiled-experiments-remove-bad-reps.xlsx")

calibration_dict, pred_df, A0_df = tfscreen.calibration.calibrate(df,
                                        "2025-09-16_calibration.json",
                                        bg_order=0)

# %%
plot_color_dict = {'background':"gray",
                   'kanR-kan':"wheat",
                   'kanR+kan':"orange",
                   'pheS-4CP':"lightgreen",
                   'pheS+4CP':"darkgreen"}
fig, ax = tfscreen.calibration.plot.fit_summary(pred_df,A0_df,calibration_dict,plot_color_dict)

# %%
fig, ax = tfscreen.calibration.plot.indiv_replicates(pred_df)

# %%
pred_df
# Out:
#      replicate pre_condition  pre_time condition  time titrant_name  \
# 0            1      pheS-4CP        30  pheS+4CP   166         iptg
# 1            1      pheS-4CP        30  pheS+4CP   166         iptg
# 2            1      pheS-4CP        30  pheS+4CP   166         iptg
# 3            1      pheS-4CP        30  pheS+4CP   166         iptg
# 4            1      pheS-4CP        30  pheS+4CP   166         iptg
# ..         ...           ...       ...       ...   ...          ...
# 476         15      pheS-4CP        30  pheS-4CP   135         iptg
# 477         15      pheS-4CP        30  pheS-4CP   135         iptg
# 478         15      pheS-4CP        30  pheS-4CP   135         iptg
# 479         15      pheS-4CP        30  pheS-4CP   135         iptg
# 480         15      pheS-4CP        30  pheS-4CP   135         iptg
#
#      titrant_conc    cfu_per_mL  cfu_per_mL_std     theta  theta_std  \
# 0          0.0000  1.083498e+08    2.166996e+06  1.000000   0.020000
# ...
