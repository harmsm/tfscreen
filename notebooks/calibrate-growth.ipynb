# %%
import tfscreen
from tfscreen.calibration import (
    calibrate,
    plot
)

import matplotlib.pyplot as plt
    
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
df = tfscreen.util.read_dataframe("input/raw-compiled-experiments-remove-bad-reps.xlsx")
calibration_dict, pred_df, param_df = tfscreen.calibration.calibrate(df,"2025-09-16_calibration.json",no_bg_slope=True)
# Out:
# /Users/harmsm/miniconda3/lib/python3.12/site-packages/tfscreen/calibration/calibrate.py:102: UserWarning: No genotype column. Assuming all calibration genotypes are 'wt'
#   warnings.warn("No genotype column. Assuming all calibration genotypes are 'wt'")

# %%
plot_color_dict = {'background':"gray",
                   'kanR-kan':"wheat",
                   'kanR+kan':"orange",
                   'pheS-4CP':"lightgreen",
                   'pheS+4CP':"darkgreen"}
fig, ax = tfscreen.calibration.plot.fit_summary(pred_df,param_df,calibration_dict,plot_color_dict)

# %%
fig, ax = tfscreen.calibration.plot.indiv_replicates(pred_df)
