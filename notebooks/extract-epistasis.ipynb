# %% [markdown]
# ### Grab iptg dependent epistasis from a theta dataframe

# %%
import tfscreen
from tfscreen.analysis import extract_epistasis

df = extract_epistasis(df="demo-theta.csv",
                  obs_column='theta_est',
                  std_column='theta_std',
                  conditions="iptg",
                  scale="add",
                  drop_extra_columns=True)

df
# Out:
#         genotype    ep_obs    ep_std    wt_obs    wt_std    m1_obs    m1_std  \
# 0      V30A/Q89A  0.029148  0.067626  0.887277  0.004187  0.904154  0.017300
# 1      V30A/Q89A -0.067637  0.067368  0.891422  0.004202  0.918717  0.017198
# 2      V30A/Q89A  0.053650  0.070422  0.878003  0.004193  0.868522  0.017299
# 3      V30A/Q89A  0.067390  0.068398  0.845093  0.004225  0.802217  0.017395
# 4      V30A/Q89A  0.071279  0.066742  0.660348  0.004286  0.588393  0.017637
# ...          ...       ...       ...       ...       ...       ...       ...
# 79195  E36Y/V95Y  0.129401  0.199023  0.845093  0.004225  0.847356  0.019388
# 79196  E36Y/V95Y -0.235316  0.209861  0.660348  0.004286  0.646629  0.019637
# 79197  E36Y/V95Y -0.334629  0.199321  0.310550  0.004280  0.303228  0.019856
# 79198  E36Y/V95Y -0.006888  0.194843  0.095233  0.004279  0.102481  0.020003
# 79199  E36Y/V95Y  0.110485  0.192423  0.029668  0.004254  0.030326  0.019784
#
# ...

# %%
df.sort_values(["genotype"])
