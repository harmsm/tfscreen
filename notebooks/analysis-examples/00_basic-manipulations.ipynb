# %%
import tfscreen
from tfscreen.plot import heatmap
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Basic manipulations
#
# How to read in data and manipulate it using tfscreen and the categorical genotype datatype.

# %%
theta_file = "theta.csv"

# This reads in the dataframe in a clean way, dropping leading index 
# entries and automatically using read_csv, read_xlsx, or just leaving
# the dataframe alone if you already loaded it
df = tfscreen.util.read_dataframe(theta_file)

# %%
# Genotype column starts as an object (str). This means if we sort it, it 
# sorts alphabetically. 
print(df["genotype"].dtype)
df.sort_values("genotype")
# Out:
# object
#     genotype titrant_name  titrant_conc  theta_est  theta_std  class  \
# 351     A32C         iptg        1.0000   0.552133   0.133079  theta
# 349     A32C         iptg        0.0300   0.842998   0.138525  theta
# 348     A32C         iptg        0.0100   1.340297   0.146708  theta
# 347     A32C         iptg        0.0030   1.534203   0.142718  theta
# 346     A32C         iptg        0.0010   1.613716   0.146837  theta
# ..       ...          ...           ...        ...        ...    ...
# 4         wt         iptg        0.0100   1.359748   0.149432  theta
# 3         wt         iptg        0.0030   1.526672   0.145191  theta
# 2         wt         iptg        0.0010   1.649798   0.153619  theta
# 1         wt         iptg        0.0001   1.752083   0.147329  theta
# 0         wt         iptg        0.0000   1.823504   0.166039  theta
#
#                       name     guess transform  scale_mu  scale_sigma  idx  \
# 351    theta_A32C_iptg_1.0  0.000251     dummy       0.0          1.0   25
# 349   theta_A32C_iptg_0.03  0.218308     dummy       0.0          1.0   23
# 348   theta_A32C_iptg_0.01  0.715383     dummy       0.0          1.0   22
# 347  theta_A32C_iptg_0.003  0.965431     dummy       0.0          1.0   21
# 346  theta_A32C_iptg_0.001  0.996037     dummy       0.0          1.0   20
# ..                     ...       ...       ...       ...          ...  ...
# 4       theta_wt_iptg_0.01  0.715383     dummy       0.0          1.0   14
# 3      theta_wt_iptg_0.003  0.965431     dummy       0.0          1.0   13
# 2      theta_wt_iptg_0.001  0.996037     dummy       0.0          1.0   12
# 1     theta_wt_iptg_0.0001  0.999960     dummy       0.0          1.0   11
# 0        theta_wt_iptg_0.0  1.000000     dummy       0.0          1.0   10
#
#      lower_bounds  upper_bounds  censored  fixed
# 351          -inf           inf     False  False
# 349          -inf           inf     False  False
# 348          -inf           inf     False  False
# 347          -inf           inf     False  False
# 346          -inf           inf     False  False
# ..            ...           ...       ...    ...
# 4            -inf           inf     False  False
# 3            -inf           inf     False  False
# 2            -inf           inf     False  False
# 1            -inf           inf     False  False
# 0            -inf           inf     False  False
#
# [1687496 rows x 16 columns]

# %%
# This function makes the genotype into a categorical datatype with the right
# sort order. Standardize makes double sure things like M98I/H29A -> H29A/M98I
# and H29A -> wt. 
df = tfscreen.genetics.set_categorical_genotype(df,standardize=True,sort=True)
df
# Out:
#                genotype titrant_name  titrant_conc  theta_est  theta_std  \
# 0                    wt         iptg        0.0000   1.823504   0.166039
# 1                    wt         iptg        0.0001   1.752083   0.147329
# 2                    wt         iptg        0.0010   1.649798   0.153619
# 3                    wt         iptg        0.0030   1.526672   0.145191
# 4                    wt         iptg        0.0100   1.359748   0.149432
# ...                 ...          ...           ...        ...        ...
# 1687490  M42I/H74A/K84L         iptg        0.0010   0.810740   0.155545
# 1687491  M42I/H74A/K84L         iptg        0.0030   0.759494   0.147623
# 1687492  M42I/H74A/K84L         iptg        0.0100   0.727106   0.152426
# 1687493  M42I/H74A/K84L         iptg        0.0300   0.876118   0.149091
# 1687495  M42I/H74A/K84L         iptg        1.0000   0.978082   0.143350
#
#          class                             name     guess transform  scale_mu  \
# 0        theta                theta_wt_iptg_0.0  1.000000     dummy       0.0
# 1        theta             theta_wt_iptg_0.0001  0.999960     dummy       0.0
# 2        theta              theta_wt_iptg_0.001  0.996037     dummy       0.0
# 3        theta              theta_wt_iptg_0.003  0.965431     dummy       0.0
# 4        theta               theta_wt_iptg_0.01  0.715383     dummy       0.0
# ...        ...                              ...       ...       ...       ...
# 1687490  theta  theta_M42I/H74A/K84L_iptg_0.001  0.996037     dummy       0.0
# 1687491  theta  theta_M42I/H74A/K84L_iptg_0.003  0.965431     dummy       0.0
# 1687492  theta   theta_M42I/H74A/K84L_iptg_0.01  0.715383     dummy       0.0
# 1687493  theta   theta_M42I/H74A/K84L_iptg_0.03  0.218308     dummy       0.0
# 1687495  theta    theta_M42I/H74A/K84L_iptg_1.0  0.000251     dummy       0.0
#
#          scale_sigma  idx  lower_bounds  upper_bounds  censored  fixed
# 0                1.0   10          -inf           inf     False  False
# 1                1.0   11          -inf           inf     False  False
# 2                1.0   12          -inf           inf     False  False
# 3                1.0   13          -inf           inf     False  False
# 4                1.0   14          -inf           inf     False  False
# ...              ...  ...           ...           ...       ...    ...
# 1687490          1.0   20          -inf           inf     False  False
# 1687491          1.0   21          -inf           inf     False  False
# 1687492          1.0   22          -inf           inf     False  False
# 1687493          1.0   23          -inf           inf     False  False
# 1687495          1.0   25          -inf           inf     False  False
#
# [1687496 rows x 16 columns]

# %%
# if we sort on genotype now, it works. 
df.sort_values("genotype")
# Out:
#                genotype titrant_name  titrant_conc  theta_est  theta_std  \
# 0                    wt         iptg        0.0000   1.823504   0.166039
# 1                    wt         iptg        0.0001   1.752083   0.147329
# 2                    wt         iptg        0.0010   1.649798   0.153619
# 3                    wt         iptg        0.0030   1.526672   0.145191
# 4                    wt         iptg        0.0100   1.359748   0.149432
# ...                 ...          ...           ...        ...        ...
# 1687489  M42I/H74A/K84L         iptg        0.0001   0.920603   0.150240
# 1687490  M42I/H74A/K84L         iptg        0.0010   0.810740   0.155545
# 1687491  M42I/H74A/K84L         iptg        0.0030   0.759494   0.147623
# 1687492  M42I/H74A/K84L         iptg        0.0100   0.727106   0.152426
# 1687495  M42I/H74A/K84L         iptg        1.0000   0.978082   0.143350
#
#          class                              name     guess transform  \
# 0        theta                 theta_wt_iptg_0.0  1.000000     dummy
# 1        theta              theta_wt_iptg_0.0001  0.999960     dummy
# 2        theta               theta_wt_iptg_0.001  0.996037     dummy
# 3        theta               theta_wt_iptg_0.003  0.965431     dummy
# 4        theta                theta_wt_iptg_0.01  0.715383     dummy
# ...        ...                               ...       ...       ...
# 1687489  theta  theta_M42I/H74A/K84L_iptg_0.0001  0.999960     dummy
# 1687490  theta   theta_M42I/H74A/K84L_iptg_0.001  0.996037     dummy
# 1687491  theta   theta_M42I/H74A/K84L_iptg_0.003  0.965431     dummy
# 1687492  theta    theta_M42I/H74A/K84L_iptg_0.01  0.715383     dummy
# 1687495  theta     theta_M42I/H74A/K84L_iptg_1.0  0.000251     dummy
#
#          scale_mu  scale_sigma  idx  lower_bounds  upper_bounds  censored  \
# 0             0.0          1.0   10          -inf           inf     False
# 1             0.0          1.0   11          -inf           inf     False
# 2             0.0          1.0   12          -inf           inf     False
# 3             0.0          1.0   13          -inf           inf     False
# 4             0.0          1.0   14          -inf           inf     False
# ...           ...          ...  ...           ...           ...       ...
# 1687489       0.0          1.0   19          -inf           inf     False
# 1687490       0.0          1.0   20          -inf           inf     False
# 1687491       0.0          1.0   21          -inf           inf     False
# 1687492       0.0          1.0   22          -inf           inf     False
# 1687495       0.0          1.0   25          -inf           inf     False
#
#          fixed
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 1687489  False
# 1687490  False
# 1687491  False
# 1687492  False
# 1687495  False
#
# [1687496 rows x 16 columns]

# %%
# This extracts a single genotype
out_df = df[df["genotype"] == "H74A"]
out_df
# Out:
#      genotype titrant_name  titrant_conc  theta_est  theta_std  class  \
# 4863     H74A         iptg        1.0000   0.617530   0.132919  theta
# 4862     H74A         iptg        0.1000   0.474287   0.137036  theta
# 4861     H74A         iptg        0.0300   0.533357   0.138806  theta
# 4860     H74A         iptg        0.0100   0.428880   0.142753  theta
# 4857     H74A         iptg        0.0001   0.784549   0.139311  theta
# 4858     H74A         iptg        0.0010   0.665968   0.144305  theta
# 4856     H74A         iptg        0.0000   1.011603   0.154134  theta
# 4859     H74A         iptg        0.0030   0.527075   0.136995  theta
#
#                         name     guess transform  scale_mu  scale_sigma  idx  \
# 4863     theta_H74A_iptg_1.0  0.000251     dummy       0.0          1.0   25
# 4862     theta_H74A_iptg_0.1  0.024519     dummy       0.0          1.0   24
# 4861    theta_H74A_iptg_0.03  0.218308     dummy       0.0          1.0   23
# 4860    theta_H74A_iptg_0.01  0.715383     dummy       0.0          1.0   22
# 4857  theta_H74A_iptg_0.0001  0.999960     dummy       0.0          1.0   19
# 4858   theta_H74A_iptg_0.001  0.996037     dummy       0.0          1.0   20
# 4856     theta_H74A_iptg_0.0  1.000000     dummy       0.0          1.0   18
# 4859   theta_H74A_iptg_0.003  0.965431     dummy       0.0          1.0   21
#
#       lower_bounds  upper_bounds  censored  fixed
# 4863          -inf           inf     False  False
# 4862          -inf           inf     False  False
# 4861          -inf           inf     False  False
# 4860          -inf           inf     False  False
# 4857          -inf           inf     False  False
# 4858          -inf           inf     False  False
# 4856          -inf           inf     False  False
# 4859          -inf           inf     False  False

# %%
# This function expands the gentoype column into sites. All of the NAN
# values are for wildtype. 
out_df = tfscreen.genetics.expand_genotype_columns(df)
out_df
# Out:
#                genotype wt_aa_1  resid_1 mut_aa_1 wt_aa_2  resid_2 mut_aa_2  \
# 0                    wt     NaN     <NA>      NaN     NaN     <NA>      NaN
# 1                    wt     NaN     <NA>      NaN     NaN     <NA>      NaN
# 2                    wt     NaN     <NA>      NaN     NaN     <NA>      NaN
# 3                    wt     NaN     <NA>      NaN     NaN     <NA>      NaN
# 4                    wt     NaN     <NA>      NaN     NaN     <NA>      NaN
# ...                 ...     ...      ...      ...     ...      ...      ...
# 1687490  M42I/H74A/K84L       M       42        I       H       74        A
# 1687491  M42I/H74A/K84L       M       42        I       H       74        A
# 1687492  M42I/H74A/K84L       M       42        I       H       74        A
# 1687493  M42I/H74A/K84L       M       42        I       H       74        A
# 1687495  M42I/H74A/K84L       M       42        I       H       74        A
#
#         wt_aa_3  resid_3 mut_aa_3  ...                             name  \
# 0           NaN     <NA>      NaN  ...                theta_wt_iptg_0.0
# 1           NaN     <NA>      NaN  ...             theta_wt_iptg_0.0001
# 2           NaN     <NA>      NaN  ...              theta_wt_iptg_0.001
# 3           NaN     <NA>      NaN  ...              theta_wt_iptg_0.003
# 4           NaN     <NA>      NaN  ...               theta_wt_iptg_0.01
# ...         ...      ...      ...  ...                              ...
# 1687490       K       84        L  ...  theta_M42I/H74A/K84L_iptg_0.001
# 1687491       K       84        L  ...  theta_M42I/H74A/K84L_iptg_0.003
# 1687492       K       84        L  ...   theta_M42I/H74A/K84L_iptg_0.01
# 1687493       K       84        L  ...   theta_M42I/H74A/K84L_iptg_0.03
# 1687495       K       84        L  ...    theta_M42I/H74A/K84L_iptg_1.0
#
#             guess  transform  scale_mu  scale_sigma idx lower_bounds  \
# 0        1.000000      dummy       0.0          1.0  10         -inf
# 1        0.999960      dummy       0.0          1.0  11         -inf
# 2        0.996037      dummy       0.0          1.0  12         -inf
# 3        0.965431      dummy       0.0          1.0  13         -inf
# 4        0.715383      dummy       0.0          1.0  14         -inf
# ...           ...        ...       ...          ...  ..          ...
# 1687490  0.996037      dummy       0.0          1.0  20         -inf
# 1687491  0.965431      dummy       0.0          1.0  21         -inf
# 1687492  0.715383      dummy       0.0          1.0  22         -inf
# 1687493  0.218308      dummy       0.0          1.0  23         -inf
# 1687495  0.000251      dummy       0.0          1.0  25         -inf
#
#          upper_bounds censored  fixed
# 0                 inf    False  False
# 1                 inf    False  False
# 2                 inf    False  False
# 3                 inf    False  False
# 4                 inf    False  False
# ...               ...      ...    ...
# 1687490           inf    False  False
# 1687491           inf    False  False
# 1687492           inf    False  False
# 1687493           inf    False  False
# 1687495           inf    False  False
#
# [1687496 rows x 26 columns]
